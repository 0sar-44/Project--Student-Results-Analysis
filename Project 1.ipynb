# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("Expanded_data_with_more_features.csv")
print(df.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# # Drop unnamed column #

# %%
df = df.drop('Unnamed: 0',axis=1)
print(df.head())
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard      NaN
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# ...

# %% [markdown]
# # Change weekly study hours columns #

# %%
df["WklyStudyHours"]=df["WklyStudyHours"].str.replace(" 5 -Oct","5-10")
df.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard      NaN
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# ...

# %% [markdown]
# # Gender Distribution #

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot(x='Gender',data=df)
plt.title("Gender distribution")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
gb = df.groupby("ParentEduc").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb)
#From the above chart we have concluded that there is impressive impact on the
#student's score due to their parent's Education status.#
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
sns.heatmap(gb,annot=True)
plt.title("Relationship between parent's Education and student's score.")
plt.show()

# %%
gb1 = df.groupby("ParentMaritalStatus").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb1)

#From the above chart we have concluded that there is no/neglible impact on the
#student's score due to their parent's martial status.#
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
sns.heatmap(gb1,annot=True)
plt.title("Relationship between parent's MaritalStatus and student's score.")
plt.show()

# %%
gb2 = df.groupby("EthnicGroup").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb2)
# Out:
#              MathScore  ReadingScore  WritingScore
# EthnicGroup
# group A      62.991888     66.787742     65.251915
# group B      63.490216     67.320460     65.895125
# group C      64.695723     68.438233     66.999240
# group D      67.666400     70.382247     70.890844
# group E      75.298936     74.251423     72.677060

# %%
sns.heatmap(gb2,annot=True)
plt.title("Relationship between EthnicGroup and student's score.")
plt.show()

# %%
gb3 = df.groupby("WklyStudyHours").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb3)
# Out:
#                 MathScore  ReadingScore  WritingScore
# WklyStudyHours
# 5 - 10          66.870491     69.660532     68.636280
# < 5             64.580359     68.176135     67.090192
# > 10            68.696655     70.365436     69.777778

# %%
sns.heatmap(gb3,annot=True)
plt.title("Relationship between WklyStudyHours and student's score.")
plt.show()

# %%
sns.boxplot(data=df,x="MathScore")
plt.show()

# %%
sns.boxplot(data=df,x="ReadingScore")
plt.show()

# %%
sns.boxplot(data=df,x="WritingScore")
plt.show()

# %%
print(df["EthnicGroup"].unique())
# Out:
# [nan 'group C' 'group B' 'group A' 'group D' 'group E']

# %% [markdown]
# # Distrubution of Ethnic Groups #

# %%
groupA=df.loc[(df['EthnicGroup']=="group A")].count()
groupB=df.loc[(df['EthnicGroup']=="group B")].count()
groupC=df.loc[(df['EthnicGroup']=="group C")].count()
groupD=df.loc[(df['EthnicGroup']=="group D")].count()
groupE=df.loc[(df['EthnicGroup']=="group E")].count()

l=["groupA","groupB","groupC","groupD","groupE"]
mlist=[groupA["EthnicGroup"],groupB["EthnicGroup"],groupC["EthnicGroup"],groupD["EthnicGroup"],groupE["EthnicGroup"]]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
print(mlist)
plt.title("Distribution Of Ethnic Groups")
plt.show()
# Out:
# [2219, 5826, 9212, 7503, 4041]

# %%
sns.countplot(data=df,x='EthnicGroup')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
gb4 = df.groupby("PracticeSport").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb4)
# Out:
#                MathScore  ReadingScore  WritingScore
# PracticeSport
# never          64.171079     68.337662     66.522727
# regularly      67.839155     69.943019     69.604003
# sometimes      66.274831     69.241307     68.072438

# %%
sns.heatmap(gb4,annot=True)
plt.title("Relationship between PracticeSport and student's score.")
plt.show()

# %%
gb5 = df.groupby("TransportMeans").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb5)
# Out:
#                 MathScore  ReadingScore  WritingScore
# TransportMeans
# private         66.511354     69.472364     68.509593
# school_bus      66.674636     69.446206     68.492351

# %%
sns.heatmap(gb5,annot=True)
plt.title("Relationship between TransportMeans and student's score.")
plt.show()

# %%
gb6 = df.groupby("TestPrep").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb6)
# Out:
#            MathScore  ReadingScore  WritingScore
# TestPrep
# completed   69.54666     73.732998     74.703265
# none        64.94877     67.051071     65.092756

# %%
sns.heatmap(gb6,annot=True)
plt.title("Relationship between TestPrep and student's score.")
plt.show()

# %%
gb7 = df.groupby("Gender").agg({"MathScore":'mean',"ReadingScore":"mean","WritingScore":"mean"})
print(gb7)
# Out:
#         MathScore  ReadingScore  WritingScore
# Gender
# female  64.080654     72.853216     72.856457
# male    69.069856     65.854571     63.920418

# %%
sns.heatmap(gb7,annot=True)
plt.title("Relationship between Gender and student's score.")
plt.show()
# Female students get good avergae score as compared to males students.

# %%
sns.countplot(data=df,x='TestPrep')
for bars in ax.containers:
    ax.bar_label(bars)
    # This show how many of them has completed or not TestPrep.

# %%
sns.countplot(data=df,x='PracticeSport')
for bars in ax.containers:
    ax.bar_label(bars)
      # This show how many of them  plays any sports or not.

# %%
sns.countplot(data=df,x='TransportMeans')
for bars in ax.containers:
    ax.bar_label(bars)
       # This shows mode of transport taken by Genders.

# %%
sns.countplot(data=df,x='WklyStudyHours')
for bars in ax.containers:
    ax.bar_label(bars)
       # This shows no of weekly hours study .

# %%
reg=df.loc[(df['PracticeSport']=="regularly")].count()
somet=df.loc[(df['PracticeSport']=="sometimes")].count()
somet=df.loc[(df['PracticeSport']=="sometimes")].count()
never=df.loc[(df['PracticeSport']=="never")].count()
somet=df.loc[(df['PracticeSport']=="sometimes")].count()

l=["reg","somet","somet","never","somet"]
mlist=[reg["PracticeSport"],somet["PracticeSport"],somet["PracticeSport"],never["PracticeSport"],somet["PracticeSport"]]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
print(mlist)
plt.title("Distribution Of ParticeSport")
plt.show()
# Out:
# [10793, 15213, 15213, 4004, 15213]

# %%
lessthanfive=df.loc[(df['WklyStudyHours']=="<5")].count()
btwfivetoten=df.loc[(df['WklyStudyHours']=="5-10")].count()
lessthanfive=df.loc[(df['WklyStudyHours']=="<5")].count()
btwfivetoten=df.loc[(df['WklyStudyHours']=="5-10")].count()
btwfivetoten=df.loc[(df['WklyStudyHours']=="5-10")].count()

l=["lessthanfive","btwfivetoten","lessthanfive","btwfivetoten","btwfivetoten"]
mlist=[reg["WklyStudyHours"],somet["WklyStudyHours"],somet["WklyStudyHours"],never["WklyStudyHours"],somet["WklyStudyHours"]]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
print(mlist)
plt.title("Distribution Of  weeklystudy hours.")
plt.show()
# Out:
# [10471, 14744, 14744, 3860, 14744]

# %%
Btech=df.loc[(df['ParentEduc']=="bachelor's degree")].count()
someclg=df.loc[(df['ParentEduc']=="some college")].count()
masterdeg=df.loc[(df['ParentEduc']=="master's degree")].count()
assocDeg=df.loc[(df['ParentEduc']=="associate's degree")].count()
someclg=df.loc[(df['ParentEduc']=="some college")].count()

l=["Btech","someclg","masterdeg","assocDeg","someclg"]
mlist=[reg["ParentEduc"],somet["ParentEduc"],somet["ParentEduc"],never["ParentEduc"],somet["ParentEduc"]]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
print(mlist)
plt.title("Distribution Of  ParentEduc.")
plt.show()
# Out:
# [10151, 14321, 14321, 3743, 14321]

# %%
none=df.loc[(df['TestPrep']=="none")].count()
nan=df.loc[(df['TestPrep']=="NaN")].count()
none=df.loc[(df['TestPrep']=="none")].count()
none=df.loc[(df['TestPrep']=="none")].count()
none=df.loc[(df['TestPrep']=="none")].count()

l=["none","nan","none","none","none"]
mlist=[reg["TestPrep"],somet["TestPrep"],somet["TestPrep"],never["TestPrep"],somet["TestPrep"]]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
print(mlist)
plt.title("Distribution Of  TestPrep")
plt.show()
# Out:
# [10141, 14310, 14310, 3762, 14310]
